# %% [markdown]
# ## Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Load data

# %%
path = '/content/drive/MyDrive/Tesi/data/Dati/'

load_AS = pd.read_csv(path + 'results/load_test_predictions_ARIMA_SARIMA.csv')
load_LG = pd.read_csv(path + 'results/load_test_predictions_LSTM_GRU.csv')

load_weather_AS = pd.read_csv(path + 'results/load_weather_test_predictions_ARIMA_SARIMA.csv')
load_weather_LG = pd.read_csv(path + 'results/load_weather_test_predictions_LSTM_GRU.csv')

prod_AS = pd.read_csv(path + 'results/prod_test_predictions_ARIMA_SARIMA.csv')
prod_LG = pd.read_csv(path + 'results/prod_test_predictions_LSTM_GRU.csv')

prod_weather_AS = pd.read_excel(path + 'results/prod_weather_test_predictions_ARIMA_SARIMA.xlsx')
prod_weather_LG = pd.read_excel(path + 'results/prod_weather_test_predictions_LSTM_GRU.xlsx')

# %%
load_AS = load_AS.drop('Unnamed: 0', axis=1)
